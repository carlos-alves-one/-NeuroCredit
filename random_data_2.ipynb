# %% [markdown]
# ### Goldsmiths University of London
# ### Author....: Carlos Manuel de Oliveira Alves
# ### Student...: cdeol003
# ### Created...: 26/01/2023
# ### FYP.......: NeuroCredit

# %%
# Import pandas library
import pandas as pd

# %%
# Import random to generate random data
import random

# %%
# Import os to create a directory
import os

# %%
# Declare a list to store the data
data = []

# Generate 1000 random records
for i in range(1000):

    # Credit history
    credit_history_list = ["Excellent", "Good", "Fair", "Poor"]
    credit_history = random.choice(credit_history_list)

    # Income and employment information
    income = random.randint(10000, 50000)
    employment_status_list = ["Employed", "Self-Employed", "Unemployed"]
    employment_status = random.choice(employment_status_list)

    # Collateral information and assets value
    collateral_list = ["House", "Car", "None", "Other", "Land", "Investment"]
    collateral = random.choice(collateral_list)
    assets_value = random.randint(10000, 50000)

    # Debt-to-income ratio
    debt_to_income_ratio = random.randint(0, 100)

    # Payment history
    payment_history_list = ["Excellent", "Good", "Fair", "Poor"]
    payment_history = random.choice(payment_history_list)

    # Length of credit history
    length_of_credit_history = random.randint(0, 100)

    # Number of credit inquiries
    number_of_credit_inquiries = random.randint(0, 5)

    # Number of credit accounts
    number_of_credit_accounts = random.randint(0, 5)

    # Number of credit accounts opened in the last 12 months
    number_of_credit_accounts_opened_last_12_months = random.randint(0, 5)

    # Type of credit accounts
    type_of_credit_accounts_list = ["Mortgage", "Auto", "Student", "Personal", "Other"]
    type_of_credit_accounts = random.choice(type_of_credit_accounts_list)

    # Current balance of credit accounts
    current_balance_of_credit_accounts = random.randint(0, 20000)

    # Total credit limit
    total_credit_limit = random.randint(0, 20000)

    # Total credit utilization
    total_credit_utilization = random.randint(0, 100)

    # Public records and collections
    public_records_and_collections_list = ["None", "Bankruptcy", "Tax Lien", "Judgement", "Other", "Collection"]
    public_records_and_collections = random.choice(public_records_and_collections_list)

    # Loan amount
    loan_amount = random.randint(1000, 5000)

    # Purpose of the loan
    purpose_of_loan_list = ["Debt Consolidation", "Home Improvement", "Business", "Car Financing", "Other"]
    purpose_of_loan = random.choice(purpose_of_loan_list)

    # Saving account balance
    saving_account_balance = random.randint(0, 20000)

    # >> Approval status:
    # 1. If credit history is excellent, then the loan is approved
    # 2. If credit history is good, then the loan is approved if the income is greater than 25,000 or the assets value 
    #    is greater than 20,000
    # 3. If credit history is fair, then the loan is approved if the debt-to-income ratio is less than 0.3 and the payment 
    #    history is good
    # 4. If credit history is poor, then the loan is approved if the length of credit history is greater than 10, the number 
    #    of credit inquiries is less than 6, the number of credit accounts is greater than 8, the number of credit accounts 
    #    opened in the last 12 months is less than 2, the type of credit accounts is good,
    #    and the current balance of credit accounts is less than 30,000
    # 5. If credit history is unknown, then the loan is approved if the total credit limit is greater than 50,000 and the 
    #    total credit utilization is less than 0.3

    # Create a function to apply the credit approval rules
    def credit_approval(credit_history, income, employment_status, collateral, assets_value, debt_to_income_ratio, 
                        payment_history, length_of_credit_history, number_of_credit_inquiries, number_of_credit_accounts, 
                        number_of_credit_accounts_opened_last_12_months, type_of_credit_accounts, 
                        current_balance_of_credit_accounts, total_credit_limit, total_credit_utilization, 
                        public_records_and_collections, loan_amount, purpose_of_loan, saving_account_balance):
        
        # Initialize the approval status
        approval_status = "Unknown"

        # Set the percentage chance of approval
        approval_chance = 70 

        # Create the rules for credit approval using appropriate logic and with percentage chance of approval
        if credit_history == "Good":

            # Check if the income is greater than 25,000
            if income >= 25000:

                # Check if the employment status is employed or self-employed
                if employment_status == "Employed" or employment_status == "Self-Employed":

                    # Create random percentage chance of approval
                    if random.randint(0, 100) < approval_chance:
                        approval_status = 1

                    else:
                        approval_status = 0

                # Check the debt-to-income ratio and payment history
                elif debt_to_income_ratio < 0.3 and payment_history == "Good":

                    # Create random percentage chance of approval
                    if random.randint(0, 100) < approval_chance:
                        approval_status = 1
                    else:
                        approval_status = 0
                        
                else:
                    approval_status = 0

            # Check if the assets value is greater than 20,000
            else:
                if assets_value >= 20000:

                    # Create random percentage chance of approval
                    if random.randint(0, 100) < approval_chance:
                        approval_status = 1
                    else:
                        approval_status = 0

                else:
                    approval_status = 0

        # Check if the credit history is bad
        elif credit_history == "Bad":

            # Check if the length of credit history is greater than 10, the number of credit inquiries is less than 6,
            # the number of credit accounts is greater than 8, the number of credit accounts opened in the last 12 
            # months is less than 2, the type of credit accounts is good, and the current balance of credit accounts 
            # is less than 30,000 and the total credit limit is greater than 50,000 and the total credit utilization 
            # is less than 0.3 and total credit utilization is less than 60% and the public records and collections 
            # is none
            if (length_of_credit_history >= 10 
                and number_of_credit_inquiries < 6 
                and number_of_credit_accounts > 8 
                and number_of_credit_accounts_opened_last_12_months < 2 
                and type_of_credit_accounts == "Good" 
                and current_balance_of_credit_accounts < 30000 
                and total_credit_limit > 50000 
                and total_credit_utilization < 60
                and public_records_and_collections == "None"):

                # Create random percentage chance of approval
                if random.randint(0, 100) < approval_chance:
                    approval_status = 1
                else:
                    approval_status = 0

            else:
                approval_status = 0
                
        else:
            approval_status = 0

        # Check if the loan amount is less than the saving account balance
        if approval_status == 1:
            if saving_account_balance > loan_amount:
                approval_status = 1
            else:
                approval_status = 0

        # Return the approval status
        return approval_status

    # Append the data to the list
    data.append({
        "credit_history": credit_history,
        "employment_status": employment_status,
        "collateral": collateral,
        "payment_history": payment_history,
        "type_of_credit_accounts": type_of_credit_accounts,
        "public_records_and_collections": public_records_and_collections,
        "purpose_of_loan": purpose_of_loan,
        "income": income,
        "assets_value": assets_value,
        "debt_to_income_ratio": debt_to_income_ratio,
        "length_of_credit_history": length_of_credit_history,
        "number_of_credit_inquiries": number_of_credit_inquiries,
        "number_of_credit_accounts": number_of_credit_accounts,
        "number_of_credit_accounts_opened_last_12_months": number_of_credit_accounts_opened_last_12_months,
        "current_balance_of_credit_accounts": current_balance_of_credit_accounts,
        "total_credit_limit": total_credit_limit,
        "total_credit_utilization": total_credit_utilization,
        "loan_amount": loan_amount,
        "saving_account_balance": saving_account_balance,
        "approval_status": credit_approval(credit_history, income, employment_status, collateral, 
                                            assets_value, debt_to_income_ratio, payment_history, length_of_credit_history,
                                            number_of_credit_inquiries, number_of_credit_accounts, 
                                            number_of_credit_accounts_opened_last_12_months, type_of_credit_accounts,
                                            current_balance_of_credit_accounts, total_credit_limit, total_credit_utilization, 
                                            public_records_and_collections, loan_amount,
                                            purpose_of_loan, saving_account_balance)
    })

# Create a dataframe from the list
df = pd.DataFrame(data)

# Save the dataframe to a csv file
df.to_csv("data.csv", index=False)

# %%
# Print the first 5 rows of the dataframe as columns for better readability
df.head().T

'''
pd.read_csv is a function in the panda's library in Python that is used to read a CSV (Comma Separated Values) 
file and convert it into a pandas DataFrame.
Example:
df = pd.read_csv('file_name.csv')
'''
# Out:
# "\npd.read_csv is a function in the panda's library in Python that is used to read a CSV (Comma Separated Values) \nfile and convert it into a pandas DataFrame.\nExample:\ndf = pd.read_csv('file_name.csv')\n"

# %%
# Print the number of approved and rejected loans
df["approval_status"].value_counts()
# Out:
# 0    895
# 1    105
# Name: approval_status, dtype: int64

# %%
# Print the first 5 rows with approved loans
df[df["approval_status"] == "Approved"].head(5).T
# Out:
# Empty DataFrame
# Columns: []
# Index: [credit_history, employment_status, collateral, payment_history, type_of_credit_accounts, public_records_and_collections, purpose_of_loan, income, assets_value, debt_to_income_ratio, length_of_credit_history, number_of_credit_inquiries, number_of_credit_accounts, number_of_credit_accounts_opened_last_12_months, current_balance_of_credit_accounts, total_credit_limit, total_credit_utilization, loan_amount, saving_account_balance, approval_status]

# %%
# Print the info of the dataset
df.info()
'''
df.info() is a method in pandas that is used to get a concise summary of the DataFrame, including the number of 
non-null values in each column, the data types of each column, and the memory usage of the DataFrame.
'''
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   credit_history                                   1000 non-null   object
#  1   employment_status                                1000 non-null   object
#  2   collateral                                       1000 non-null   object
#  3   payment_history                                  1000 non-null   object
#  4   type_of_credit_accounts                          1000 non-null   object
#  5   public_records_and_collections                   1000 non-null   object
#  6   purpose_of_loan                                  1000 non-null   object
#  7   income                                           1000 non-null   int64
#  8   assets_value                                     1000 non-null   int64
# ...

# %%
# Describe statistics of the numerical columns 
df.describe().T
'''
The df.describe() method in pandas is used to generate summary statistics of various features of a DataFrame. 
It returns a new DataFrame that contains the count, mean, standard deviation, minimum, 25th percentile, median, 
75th percentile, and maximum of each numerical column in the original DataFrame.
'''
# Out:
# '\nThe df.describe() method in pandas is used to generate summary statistics of various features of a DataFrame. \nIt returns a new DataFrame that contains the count, mean, standard deviation, minimum, 25th percentile, median, \n75th percentile, and maximum of each numerical column in the original DataFrame.\n'

# %%
# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "end_to_end_project"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

# %%
# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
# Create a function top save the figures
def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %%
# Plot the histogram of the numerical columns of the dataframe
# %matplotlib inline

# Import matplotlib for plotting
import matplotlib.pyplot as plt

# Plot the histogram of the numerical columns
df.hist(bins=50, figsize=(20,15))

# Save the figure
save_fig("attribute_histogram_plots")

# Show the plot
plt.show()
# Out:
# Saving figure attribute_histogram_plots
