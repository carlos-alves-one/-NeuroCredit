# %% [markdown]
# ### Goldsmiths University of London
# ### Author....: Carlos Manuel de Oliveira Alves
# ### Student...: cdeol003
# ### Created...: 08/02/2023
# ### FYP.......: NeuroCredit

# %%
# Importing the pandas library to read the data
import pandas as pd

# %%
# Reading the data with credit loans data
data = pd.read_csv('data.csv')

# %%
# Printing the first 5 rows of the data
data.head().T
# Out:
#                                                              0              1  \
# credit_history                                            Fair           Good
# income                                                   34084          20938
# employment_status                                     Employed  Self-Employed
# collateral                                                Land            Car
# assets_value                                             39837          33241
# debt_to_income_ratio                                        76             53
# payment_history                                      Excellent           Poor
# length_of_credit_history                                    84             59
# number_of_credit_inquiries                                   5              3
# number_of_credit_accounts                                    0              3
# number_of_credit_accounts_opened_last_12_months              3              0
# type_of_credit_accounts                                   Auto           Auto
# current_balance_of_credit_accounts                       12377           1430
# total_credit_limit                                        6149          18922
# total_credit_utilization                                    80             33
# public_records_and_collections                       Judgement      Judgement
# loan_amount                                               4641           3592
# purpose_of_loan                                  Car Financing          Other
# saving_account_balance                                    3011          16448
# approval_status                                       Rejected       Approved
#
#                                                          2                 3  \
# credit_history                                        Good              Good
# income                                               20734             14186
# employment_status                                 Employed        Unemployed
# collateral                                            Land               Car
# assets_value                                         12926             16586
# debt_to_income_ratio                                    52                67
# payment_history                                  Excellent              Poor
# length_of_credit_history                                84                92
# number_of_credit_inquiries                               1                 5
# number_of_credit_accounts                                1                 5
# number_of_credit_accounts_opened_last_12_months          3                 0
# type_of_credit_accounts                               Auto           Student
# current_balance_of_credit_accounts                   16049              4938
# total_credit_limit                                    1197             13206
# total_credit_utilization                                57                92
# public_records_and_collections                       Other        Collection
# loan_amount                                           1955              3652
# purpose_of_loan                                      Other  Home Improvement
# saving_account_balance                                6192              7279
# approval_status                                   Rejected          Rejected
#
#                                                                 4
# credit_history                                          Excellent
# income                                                      46693
# employment_status                                      Unemployed
# collateral                                                   Land
# assets_value                                                30771
# debt_to_income_ratio                                           66
# payment_history                                         Excellent
# length_of_credit_history                                       39
# number_of_credit_inquiries                                      1
# number_of_credit_accounts                                       2
# number_of_credit_accounts_opened_last_12_months                 4
# type_of_credit_accounts                                  Mortgage
# current_balance_of_credit_accounts                          10459
# total_credit_limit                                           4011
# total_credit_utilization                                       50
# public_records_and_collections                         Collection
# loan_amount                                                  2544
# purpose_of_loan                                  Home Improvement
# saving_account_balance                                       7619
# approval_status                                          Rejected
